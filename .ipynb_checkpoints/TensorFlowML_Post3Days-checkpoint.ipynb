# %%
# Initial imports
from path import Path
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
# %matplotlib inline

# %%
# import CSV file into dataframe

file_path = Path("./GS_Test/GS_SentScoreswVOL.csv")
df = pd.read_csv(file_path)
df['Date'] = pd.to_datetime(df['Date'],format='%m/%d/%y')
df.set_index('Date',inplace=True)
df.sort_index(inplace=True)
df.dropna()
# Out:
#            Ticker        Company    Year QTR  Sent_Neg  Sent_Neu  Sent_Pos  \
# Date
# 2015-07-16     GS  Goldman Sachs  2015.0  Q2     0.025     0.852     0.123
# 2015-10-15     GS  Goldman Sachs  2015.0  Q3     0.027     0.844     0.129
# 2016-01-20     GS  Goldman Sachs  2015.0  Q4     0.029     0.863     0.107
# 2016-04-19     GS  Goldman Sachs  2016.0  Q1     0.031     0.840     0.129
# 2016-07-19     GS  Goldman Sachs  2016.0  Q2     0.024     0.864     0.112
# 2016-10-18     GS  Goldman Sachs  2016.0  Q3     0.022     0.843     0.135
# 2017-01-18     GS  Goldman Sachs  2016.0  Q4     0.024     0.835     0.140
# 2017-04-18     GS  Goldman Sachs  2017.0  Q1     0.032     0.825     0.143
# 2017-07-18     GS  Goldman Sachs  2017.0  Q2     0.032     0.840     0.128
# 2017-10-17     GS  Goldman Sachs  2017.0  Q3     0.017     0.856     0.127
# 2018-01-17     GS  Goldman Sachs  2017.0  Q4     0.020     0.878     0.101
# 2018-04-17     GS  Goldman Sachs  2018.0  Q1     0.021     0.830     0.149
# 2018-07-17     GS  Goldman Sachs  2018.0  Q2     0.020     0.842     0.138
# 2018-10-16     GS  Goldman Sachs  2018.0  Q3     0.016     0.843     0.142
# 2019-01-16     GS  Goldman Sachs  2018.0  Q4     0.021     0.857     0.121
# 2019-04-15     GS  Goldman Sachs  2019.0  Q1     0.020     0.867     0.113
# 2019-07-16     GS  Goldman Sachs  2019.0  Q2     0.025     0.863     0.112
# 2019-10-15     GS  Goldman Sachs  2019.0  Q3     0.018     0.845     0.136
#
#             Price_DayPrior  Price_DayOf  Price_DayAfter  ...  PerCngNeu  \
# Date                                                     ...
# 2015-07-16          212.96       211.18          212.46  ...     0.002
# 2015-10-15          179.51       184.96          185.18  ...    (0.009)
# 2016-01-20          156.82       153.75          151.65  ...     0.023
# 2016-04-19          159.02       162.65          166.98  ...    (0.027)
# 2016-07-19          163.33       161.41          161.77  ...     0.029
# 2016-10-18          169.00       172.63          174.51  ...    (0.024)
# 2017-01-18          235.74       234.29          231.41  ...    (0.009)
# 2017-04-18          226.26       215.59          214.09  ...    (0.012)
# 2017-07-18          229.26       223.31          222.87  ...     0.018
# 2017-10-17          242.41       236.09          242.03  ...     0.019
# 2018-01-17          258.46       253.65          250.97  ...     0.026
# 2018-04-17          257.88       253.63          254.00  ...    (0.055)
# 2018-07-17          231.44       231.02          231.24  ...     0.014
# 2018-10-16          215.22       221.70          228.28  ...     0.001
# 2019-01-16          179.91       197.08          199.09  ...     0.017
# 2019-04-15          207.84       199.91          201.84  ...     0.012
# 2019-07-16          211.58       215.52          213.30  ...    (0.005)
# 2019-10-15          205.82       206.46          207.42  ...    (0.021)
#
#             PerCngPos  PRICE_PerCng_PriorEarnings  PRICE_PerCng_DayPrior  \
# Date
# 2015-07-16    (0.061)                      0.055                 (0.008)
# 2015-10-15     0.049                      (0.124)                 0.030
# 2016-01-20    (0.171)                     (0.169)                (0.020)
# 2016-04-19     0.206                       0.058                  0.023
# 2016-07-19    (0.132)                     (0.008)                (0.012)
# 2016-10-18     0.205                       0.070                  0.021
# 2017-01-18     0.037                       0.357                 (0.006)
# 2017-04-18     0.021                      (0.080)                (0.047)
# 2017-07-18    (0.105)                      0.036                 (0.026)
# 2017-10-17    (0.008)                      0.057                 (0.026)
# 2018-01-17    (0.205)                      0.074                 (0.019)
# 2018-04-17     0.475                      (0.000)                (0.016)
# 2018-07-17    (0.074)                     (0.089)                (0.002)
# 2018-10-16     0.029                      (0.040)                 0.030
# 2019-01-16    (0.148)                     (0.111)                 0.095
# 2019-04-15    (0.066)                      0.014                 (0.038)
# 2019-07-16    (0.009)                      0.078                  0.019
# 2019-10-15     0.214                      (0.042)                 0.003
#
#             PRICE_PerCng_DayAfter PRICE_PerCng_2DaysAfter  \
# Date
# 2015-07-16                 0.006                   0.006
# 2015-10-15                 0.001                   0.004
# 2016-01-20                (0.014)                  0.020
# 2016-04-19                 0.027                   0.016
# 2016-07-19                 0.002                  (0.008)
# 2016-10-18                 0.011                   0.011
# 2017-01-18                (0.012)                 (0.009)
# 2017-04-18                (0.007)                  0.011
# 2017-07-18                (0.002)                 (0.005)
# 2017-10-17                 0.025                   0.017
# 2018-01-17                (0.011)                  0.010
# 2018-04-17                 0.001                   0.002
# 2018-07-17                 0.001                  (0.006)
# 2018-10-16                 0.030                   0.015
# 2019-01-16                 0.010                   0.028
# 2019-04-15                 0.010                   0.040
# 2019-07-16                (0.010)                 (0.005)
# 2019-10-15                 0.005                     -
#
#            VOL_PerCng_PriorEarnings VOL_PerCng_DayPrior VOL_PerCng_DayAfter  \
# Date
# 2015-07-16                   -26.3%              73.66%             -35.33%
# 2015-10-15                    29.8%              75.89%             -47.95%
# 2016-01-20                    63.8%              59.87%             -38.75%
# 2016-04-19                   -37.8%              92.39%             -17.66%
# 2016-07-19                    -7.4%              14.05%             -34.30%
# 2016-10-18                   -17.0%              46.42%             -17.99%
# 2017-01-18                    69.3%              20.92%             -39.90%
# 2017-04-18                    64.2%             197.41%             -48.42%
# 2017-07-18                   -48.6%             150.83%             -23.69%
# 2017-10-17                    10.7%             138.73%             -40.24%
# 2018-01-17                    21.4%              93.64%             -42.10%
# 2018-04-17                    17.7%             211.12%             -55.35%
# 2018-07-17                    -8.4%             183.69%             -33.73%
# 2018-10-16                   -36.2%              77.70%             -16.38%
# 2019-01-16                   156.5%             421.81%             -46.18%
# 2019-04-15                   -56.4%              29.84%             -26.67%
# 2019-07-16                   -20.2%             103.20%             -51.10%
# 2019-10-15                    56.0%             260.52%             -58.68%
#
#            VOL_PerCng_2DaysAfter
# Date
# 2015-07-16               -50.62%
# 2015-10-15               -53.40%
# 2016-01-20               -40.40%
# 2016-04-19               -28.58%
# 2016-07-19               -47.12%
# 2016-10-18               -44.87%
# 2017-01-18               -31.34%
# 2017-04-18               -58.53%
# 2017-07-18               -45.35%
# 2017-10-17               -61.76%
# 2018-01-17               -46.06%
# 2018-04-17               -60.63%
# 2018-07-17               -50.02%
# 2018-10-16               -49.44%
# 2019-01-16               -62.81%
# 2019-04-15               -36.60%
# 2019-07-16               -45.89%
# 2019-10-15               -65.10%
#
# [18 rows x 26 columns]

# %%
#See List of column titles
for col in df.columns:
    print(col)
# Out:
# Ticker
# Company
# Year
# QTR
# Sent_Neg
# Sent_Neu
# Sent_Pos
# Price_DayPrior
# Price_DayOf
# Price_DayAfter
# Price_2DaysAfter
# VOL_DayPrior
# VOL_DayOf
# VOL_DayAfter
# VOL_2DaysAfter
# PerCngNeg
# PerCngNeu
# PerCngPos
# PRICE_PerCng_PriorEarnings
# PRICE_PerCng_DayPrior
# PRICE_PerCng_DayAfter
# PRICE_PerCng_2DaysAfter
# VOL_PerCng_PriorEarnings
# VOL_PerCng_DayPrior
# VOL_PerCng_DayAfter
# VOL_PerCng_2DaysAfter

# %%
df.Price_DayOf.plot()

# %%
 df.iloc[:,4:8].dropna()
# Out:
#             Sent_Neg  Sent_Neu  Sent_Pos  Price_DayPrior
# Date
# 2015-04-16     0.019     0.850     0.131          201.10
# 2015-07-16     0.025     0.852     0.123          212.96
# 2015-10-15     0.027     0.844     0.129          179.51
# 2016-01-20     0.029     0.863     0.107          156.82
# 2016-04-19     0.031     0.840     0.129          159.02
# 2016-07-19     0.024     0.864     0.112          163.33
# 2016-10-18     0.022     0.843     0.135          169.00
# 2017-01-18     0.024     0.835     0.140          235.74
# 2017-04-18     0.032     0.825     0.143          226.26
# 2017-07-18     0.032     0.840     0.128          229.26
# 2017-10-17     0.017     0.856     0.127          242.41
# 2018-01-17     0.020     0.878     0.101          258.46
# 2018-04-17     0.021     0.830     0.149          257.88
# 2018-07-17     0.020     0.842     0.138          231.44
# 2018-10-16     0.016     0.843     0.142          215.22
# 2019-01-16     0.021     0.857     0.121          179.91
# 2019-04-15     0.020     0.867     0.113          207.84
# 2019-07-16     0.025     0.863     0.112          211.58
# 2019-10-15     0.018     0.845     0.136          205.82

# %%
X= df.iloc[:,4:8].dropna().values
y= df.iloc[:,10:11].dropna().values
# Use 70% of the data for training and the remainder for testing
split = int(0.7 * len(X))
X_train = X[: split - 1]
X_test = X[split:]
y_train = y[: split - 1]
y_test = y[split:]

# %%
scaler = StandardScaler()

# Fitting Standard Scaler
X_scaler = scaler.fit(X)
y_scaler=scaler.fit(y)

# Scaling data
X_train_scaled = X_scaler.transform(X)
#X_test_scaled=X_scaler.transform(X_test)
#y_train_scaled=y_scaler.transform(y_train)
#y_test_scaled=y_scaler.transform(y_test)

# %%
# Define the model - shallow neural net
number_hidden_nodes = 8
number_input_features = 4

nn = Sequential([
    Dense(units=number_hidden_nodes, input_dim=number_input_features, activation=tf.nn.relu),
    Dense(units=1, activation="linear")
])

# %%
# Compile the model
nn.compile(loss=tf.losses.mean_squared_error, optimizer=tf.optimizers.RMSprop(0.0099), metrics=[tf.metrics.MeanAbsoluteError(),tf.metrics.MeanSquaredError()])

# Train the model
#model_1 = nn.fit(X_scaled, y, validation_split=0.3, epochs=200,verbose=False)
model_1 = nn.fit(X_train_scaled, y,validation_split=0.3, epochs=300,verbose=False)

# %%
# Plot the train and test loss function
plt.plot(model_1.history["loss"])
plt.title("loss_function - 1 hidden layer")
plt.legend(["loss"])
plt.show()

# %%
# Define the model - deep neural net
number_input_features = 4
hidden_nodes_layer1 = 8
hidden_nodes_layer2 = 4

nn1 = Sequential([
    Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation=tf.nn.relu),
    Dense(units=hidden_nodes_layer2, activation=tf.nn.relu),
    Dense(units=hidden_nodes_layer1, activation=tf.nn.relu),
    #Dense(units=12, activation=tf.nn.selu),
    Dense(units=1, activation="linear")
])

# %%
# Compile model
#nn.compile(loss="mean_squared_error", optimizer="adam", metrics=["mse"])
nn1.compile(loss=tf.losses.mean_squared_error, optimizer=tf.optimizers.RMSprop(0.0099), metrics=[tf.metrics.MeanAbsoluteError(),tf.metrics.MeanSquaredError()])
# Fit the model
model_2 = nn1.fit(X_train_scaled, y, validation_split=0.3,epochs=300,verbose=False)

# %%
plt.plot(model_1.history["loss"])
plt.plot(model_2.history["loss"])
plt.title("loss_function - Training")
plt.legend(["1 hidden layer", "3 hidden layers"])
plt.show()

# %%
# Train vs test for shallow net
plt.plot(model_1.history["loss"])
plt.plot(model_1.history["val_loss"])
plt.title("loss_function - Training Vs. Validation - 1 hidden layer")
plt.legend(["train", "test"])
plt.show()

# %%
# Train vs test for deep net
plt.plot(model_2.history["loss"])
plt.plot(model_2.history["val_loss"])

plt.title("loss_function - Training Vs. Validation - 2 hidden layers")
plt.legend(["train", "test"])
plt.show()

# %%
plt.plot(model_2.history['mean_absolute_error'])
plt.plot(model_2.history['val_mean_absolute_error'])
plt.title("MAE_function - Training Vs. Validation - 2 hidden layers")
plt.legend(["train", "test"])

plt.show()

# %%
predictions=nn.predict(X_test_scaled)
predictions
plt.plot(predictions)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-978e55c00fb9> in <module>
# ----> 1 predictions=nn.predict(X_test_scaled)
#       2 predictions
#       3 plt.plot(predictions)
#       4 plt.show()
#
# NameError: name 'X_test_scaled' is not defined

# %%
def str2float(x):
    return float(x)
file_path = Path("./GS_Test/GS_Percent_Changes.csv")
df = pd.read_csv(file_path)
df['Date'] = pd.to_datetime(df['Date'],format='%m/%d/%y')
df.set_index('Date',inplace=True)
df.sort_index(inplace=True)
df.dropna()

X= df.iloc[:,0:3].dropna().values
y= df.PRICE_PerCng_DayPrior.dropna().values

# %%
# Fitting Standard Scaler
X_scaler = scaler.fit(X)

# Scaling data
X_scaled = X_scaler.transform(X)
number_hidden_nodes = 8
number_input_features = 3

nn = Sequential([
    Dense(units=number_hidden_nodes, input_dim=number_input_features, activation=tf.nn.selu),
    Dense(units=1, activation="linear")
])

# Compile the model
nn.compile(loss=tf.losses.mean_squared_error, optimizer=tf.optimizers.RMSprop(0.0099), metrics=[tf.metrics.MeanAbsoluteError(),tf.metrics.MeanSquaredError()])

# Train the model
model_1 = nn.fit(X_scaled, y, validation_split=0.3, epochs=200,verbose=False)

# %%
### Plot the train and test loss function
plt.plot(model_1.history["loss"])
plt.title("loss_function - 1 hidden layer")
plt.legend(["loss"])
plt.show()

# %%
number_input_features = 3
hidden_nodes_layer1 = 8
hidden_nodes_layer2 = 4

nn1 = Sequential([
    Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation=tf.nn.selu),
    Dense(units=hidden_nodes_layer2, activation=tf.nn.selu),
    Dense(units=hidden_nodes_layer1, activation=tf.nn.selu),
    Dense(units=12, activation=tf.nn.selu),
    Dense(units=1, activation="linear")
])
# Compile model
#nn.compile(loss="mean_squared_error", optimizer="adam", metrics=["mse"])
nn1.compile(loss=tf.losses.mean_squared_error, optimizer=tf.optimizers.RMSprop(0.0099), metrics=[tf.metrics.MeanAbsoluteError(),tf.metrics.MeanSquaredError()])
# Fit the model
model_2 = nn1.fit(X_scaled, y, validation_split=0.3, epochs=200,verbose=False)

# %%
plt.plot(model_1.history["loss"])
plt.plot(model_2.history["loss"])
plt.title("loss_function - Training")
plt.legend(["1 hidden layer", "4 hidden layers"])
plt.show()

# %%
# Train vs test for deep net
plt.plot(model_2.history["loss"])
plt.plot(model_2.history["val_loss"])

plt.title("loss_function - Training Vs. Validation - 2 hidden layers")
plt.legend(["train", "test"])
plt.show()

# %%
plt.plot(model_2.history['mean_absolute_error'])
plt.plot(model_2.history['val_mean_absolute_error'])
plt.title("MAE_function - Training Vs. Validation - 2 hidden layers")
plt.legend(["train", "test"])
plt.show()
